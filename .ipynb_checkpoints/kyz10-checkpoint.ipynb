# %% [markdown]
# Link To Data Set: https://data.wprdc.org/dataset/allegheny-county-walk-scores
#
# Link to Census Tracts: https://pitt.libguides.com/uscensus/alleghenycotracts
#
# Link to Census Tract Data Set: https://data.wprdc.org/dataset/pittsburgh-2014-cdbg-census-tracts/resource/6babf974-85e3-4e2b-af34-3e0c962c54d6

# %% [markdown]
# <h1>Walkability

# %% [markdown]
# One of the factors we measured for "best neighborhood" is walkability. Walkability is important because not everyone can afford a car or other sorts of transportation. Having a short and convenient walk is nice for those who want to go to the store quickly or get to school fast. I am using a data set from Western Pennsylvania Regional Data Center. This data set uses "Walk Scores." Walk Scores are based on distance, density, traffic, block length, and intersection density. Points are awarded based on these factors with no points being given for walks more than 30 minutes.

# %%
import pandas as pd

data = pd.read_csv("walkScores.csv")

#data.set_index("Census Tract", drop=True, append=False, inplace=True, verify_integrity=False)
data.head(20)
# Out:
#     Census Tract  Walk Score
# 0          10300          82
# 1          20100         100
# 2          20300          83
# 3          30500          77
# 4          40200          71
# 5          40400          82
# 6          40500          78
# 7          40600          75
# 8          40900          68
# 9          50100          60
# 10         50600          74
# 11         50900          77
# 12         51000          58
# 13         51100          62
# 14         60300          91
# 15         60500          88
# 16         70300          91
# 17         70500          88
# 18         70600          77
# 19         70800          88

# %% [markdown]
# These are the walk scores for the first 20 neighborhoods in my data set. The numbers under the census tract column represent different neighborhoods.
# Now I want to list all the neighborhoods.

# %%
data
# Out:
#      Census Tract  Walk Score
# 0           10300          82
# 1           20100         100
# 2           20300          83
# 3           30500          77
# 4           40200          71
# ..            ...         ...
# 397        981000          54
# 398        981100          51
# 399        981200          75
# 400        981800          35
# 401        982200          82
#
# [402 rows x 2 columns]

# %% [markdown]
# This represents all the data for all 402 neighborhoods in Allegheny County as represented with the 402 rows.
#
# Next, I want to represent this data with the walk scores in order from greatest to least. I want to only show the top 10.

# %%
data = data.sort_values(by='Walk Score', ascending = False).head(10)
data
# Out:
#      Census Tract  Walk Score
# 1           20100         100
# 177        445500          97
# 16          70300          91
# 14          60300          91
# 20          70900          89
# 80         220600          89
# 55         140800          88
# 19          70800          88
# 17          70500          88
# 15          60500          88

# %% [markdown]
# This shows the top 10 neighborhoods in terms of their walkability.

# %%
censusTractData = pd.read_csv("censusTracts.csv")
censusTractData
# Out:
#       _id  objectid  fid_blockg  statefp10  countyfp10  tractce10  blkgrpce10  \
# 0    3433         1         0.0       42.0         3.0    40500.0         1.0
# 1    3434         2         1.0       42.0         3.0    40400.0         1.0
# 2    3435         3         2.0       42.0         3.0    40200.0         2.0
# 3    3436         4         3.0       42.0         3.0    30500.0         2.0
# 4    3437         5         5.0       42.0         3.0    20300.0         1.0
# ..    ...       ...         ...        ...         ...        ...         ...
# 134  3567       140        57.0       42.0         3.0   250700.0         1.0
# 135  3568       141       148.0       42.0         3.0   270400.0         1.0
# 136  3569       142       217.0       42.0         3.0   980800.0         1.0
# 137  3570       143         NaN        NaN         NaN        NaN         NaN
# 138  3571       145       295.0       42.0         3.0   270300.0         2.0
#
# ...

# %% [markdown]
# This represents the Census Tracts as well as the name of the neighborhood that correlates with the tract number.
# Next, I will use this data set to manually change the Census Tract numbers on the top 10 neighborhoods in terms of walkability.

# %%
#data = data.rename(index = {20100: 'Central Business District', 445500: 'Sewickley', 70300: 'Shadyside', 
                          #60300: 'Lower Lawrenceville', 70900: 'Shadyside', 220600: 'Central Northside',
                          #140800: 'Squirrel Hill South', 70800: 'Shadyside', 70500: 'Shadyside',
                         #60500: 'Polish Hill'})

#neighborhood = ["Central Business District", "Sewickley", "Shadyside", "Lower Lawrenceville", "Shadyside", "Central Northside",
               #"Squirrel Hill South", "Shadyside", "Shadyside", "Polish Hill"]
#census_tract = [20100, 445500, 70300, 60300, 70900, 220600, 140800, 70800, 70500, 60500]

#dictionary_neighborhood = pd.DataFrame(pd.Series({20100: 'Central Business District', 445500: 'Sewickley', 70300: 'Shadyside', 
                          #60300: 'Lower Lawrenceville', 70900: 'Shadyside', 220600: 'Central Northside',
                          #140800: 'Squirrel Hill South', 70800: 'Shadyside', 70500: 'Shadyside',
                         #60500: 'Polish Hill'}))

#dictionary_neighborhood = dictionary_neighborhood.reset_index()

#data
# pd.DataFrame(census_tract, neighborhood)

# data = pd.merge(census_tract, neighborhood)
import fpsnippets
fpsnippets.census_to_neighborhoods(data['Census Tract'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a2ded5e4647b> in <module>
#      20 # data = pd.merge(census_tract, neighborhood)
#      21 import fpsnippets
# ---> 22 fpsnippets.census_to_neighborhoods(data['Census Tract'])
#
# ~/Final-Project-Best-Neighborhood-in-Pittsburgh/fpsnippets.py in census_to_neighborhoods(census_tract)
#      64     # Census to ZIP data
#      65     census_data = pandas.read_csv("./ZIP_TRACT_032020.csv")
# ---> 66     tract_filtered = census_data[census_data["TRACT"] == census_tract]
#      67     if len(tract_filtered) < 1:
#      68         return []
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ...

# %% [markdown]
# This shows the top ten neighborhoods in Allegheny County. I will use the groupby function to add the Shadyside scores together.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Central Business District to Polish Hill
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Walk Score  10 non-null     int64
# dtypes: int64(1)
# memory usage: 160.0+ bytes

# %%
data.plot.bar()

# %% [markdown]
# As you can see, all of these neighborhoods have very good walkability. There isn't too much of a difference to say that one is so much greater than the other.

# %% [markdown]
# <h1>Conclusion

# %% [markdown]
# To conclude, my graph shows the top ten neighborhoods in terms of walkability. They are all above 80 walk score.
